# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = 'drive/MyDrive/.secrets/ghpat.txt'
with open(file_path, 'r') as file:
    git_token = file.read().strip()

username = 'J031M'
repository = 'GANforCVD'
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# /content/drive/MyDrive
# Cloning into 'GANforCVD'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 29 (delta 2), reused 29 (delta 2), pack-reused 0
# Receiving objects: 100% (29/29), 16.70 MiB | 12.61 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd GANforCVD
# !mv ../Colab\ Notebooks/00-jsm-git-colab-init.ipynb ./notebooks/00-jsm-git-colab-init.ipynb
# Out:
# [Errno 2] No such file or directory: 'GANforCVD'
# /content/drive/MyDrive/GANforCVD

# %%
# !git add -A
# !git config --global user.email "ruthlessragingraspberry@gmail.com"
# !git config --global user.name "J031M"

# %%
# !git commit -m "Initilased Joel's drive with git"
# Out:
# [main f78518e] Initilased Joel's drive with git
#  1 file changed, 1 insertion(+)
#  create mode 100644 notebooks/00-jsm-git-colab-init.ipynb

# %%
# !git push
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.70 KiB | 347.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/J031M/GANforCVD
#    abd0f44..f78518e  main -> main
